# %%
import pandas as pd

data = {'category':['Sales','Operating Income','Net Income','Less: Net Income (Loss) Attributable to Noncontrolling Interests','Net Income Attributable to Tyson','Net Income Per Share Attributable to Tyson','Adjusted Operating Income','Adjusted Net Income Per Share Attributable to Tyson'],
        'Fourth Quarter-2022':[13737,766,537,-1,538,1.50,823,1.63],
        'Fourth Quarter-2021':[12811,1909,1358,3,1355,3.71,1152,2.30],
        'Twelve Months Ended-2022':[53282,4410,3249,13,3238,8.92,4414,8.73],
        'Twelve Months Ended-2021':[47049,4396,3060,11,3047,8.34,4288,8.28]}

df = pd.DataFrame(data)
print(df)
# Out:
#                                             category  Fourth Quarter-2022  \
# 0                                              Sales             13737.00
# 1                                   Operating Income               766.00
# 2                                         Net Income               537.00
# 3  Less: Net Income (Loss) Attributable to Noncon...                -1.00
# 4                   Net Income Attributable to Tyson               538.00
# 5         Net Income Per Share Attributable to Tyson                 1.50
# 6                          Adjusted Operating Income               823.00
# 7  Adjusted Net Income Per Share Attributable to ...                 1.63
#
#    Fourth Quarter-2021  Twelve Months Ended-2022  Twelve Months Ended-2021
# 0             12811.00                  53282.00                  47049.00
# 1              1909.00                   4410.00                   4396.00
# 2              1358.00                   3249.00                   3060.00
# ...

# %%
df['YoY % Change-Q4'] = (df['Fourth Quarter-2022'] - df['Fourth Quarter-2021'])/df['Fourth Quarter-2021'] * 100
df['YoY % Change-12 Months'] = (df['Twelve Months Ended-2022'] - df['Twelve Months Ended-2021'])/df['Twelve Months Ended-2021'] * 100

df
# Out:
#                                             category  Fourth Quarter-2022  \
# 0                                              Sales             13737.00
# 1                                   Operating Income               766.00
# 2                                         Net Income               537.00
# 3  Less: Net Income (Loss) Attributable to Noncon...                -1.00
# 4                   Net Income Attributable to Tyson               538.00
# 5         Net Income Per Share Attributable to Tyson                 1.50
# 6                          Adjusted Operating Income               823.00
# 7  Adjusted Net Income Per Share Attributable to ...                 1.63
#
#    Fourth Quarter-2021  Twelve Months Ended-2022  Twelve Months Ended-2021  \
# 0             12811.00                  53282.00                  47049.00
# 1              1909.00                   4410.00                   4396.00
# 2              1358.00                   3249.00                   3060.00
# ...

# %%
data = {'category': ['Sales', 'Operating Income', 'Net Income', 'Less: Net Income (Loss) Attributable to Noncontrolling Interests', 'Net Income Attributable to Tyson', 'Net Income Per Share Attributable to Tyson', 'Adjusted Operating Income', 'Adjusted Net Income Per Share Attributable to Tyson'],
        'Fourth Quarter 2022': [13737, 766, 537, 1, 538, 1.50, 823, 1.63],
        'Fourth Quarter 2021': [12811, 1909, 1358, 3, 1355, 3.71, 1152, 2.30],
        'Twelve Months Ended 2022': [53282, 4410, 3249, 13, 3238, 8.92, 4414, 8.73],
        'Twelve Months Ended 2021': [47049, 4396, 3060, 11, 3047, 8.34, 4288, 8.28]
        }

df = pd.DataFrame(data)

df
# Out:
#                                             category  Fourth Quarter 2022  \
# 0                                              Sales             13737.00
# 1                                   Operating Income               766.00
# 2                                         Net Income               537.00
# 3  Less: Net Income (Loss) Attributable to Noncon...                 1.00
# 4                   Net Income Attributable to Tyson               538.00
# 5         Net Income Per Share Attributable to Tyson                 1.50
# 6                          Adjusted Operating Income               823.00
# 7  Adjusted Net Income Per Share Attributable to ...                 1.63
#
#    Fourth Quarter 2021  Twelve Months Ended 2022  Twelve Months Ended 2021
# 0             12811.00                  53282.00                  47049.00
# 1              1909.00                   4410.00                   4396.00
# 2              1358.00                   3249.00                   3060.00
# ...
