# %%
import io
import bs4
import pandas as pd

# %% [markdown]
# # Analyzing Income Statement Table with OpenAI
# ![img](./income_table.png)

# %% [markdown]
# ## Retrieve Table from HTML

# %%
with open(r'ms_fy23_q1_html.htm','r') as f:
    content = f.read()
    soup = bs4.BeautifulSoup(content, 'html.parser')

# %%
table = soup.find('p',{'id':'INCOME_STATEMENTS'}).findNext('table')

# %%
table_txt = ''
for td in table:
    if td.text:
        table_txt+=(td.text)

# %%
print(table_txt.replace('\n',''))
# Out:
# (In millions, except per share amounts) (Unaudited) Three Months EndedDecember 31,  Six Months EndedDecember 31,                            2022 2021  2022  2021               Revenue:             Product $16,517 $20,779 $32,258 $37,410 Service and other  36,230  30,949  70,611  59,635                          Total revenue  52,747  51,728  102,869  97,045                       Cost of revenue:             Product  5,690  6,331  9,992  10,123 Service and other  11,798  10,629  22,948  20,483                       Total cost of revenue  17,488  16,960  32,940  30,606                       Gross margin  35,259  34,768  69,929  66,439 Research and development  6,844  5,758  13,472  11,357 Sales and marketing  5,679  5,379  10,805  9,926 General and administrative  2,337  1,384  3,735  2,671                       Operating income  20,399  22,247  41,917  42,485 Other income (expense), net  (60) 268  (6) 554                       Income before income taxes  20,339  22,515  41,911  43,039 Provision for income taxes  3,914  3,750  7,930  3,769                       Net income $16,425 $18,765 $33,981 $39,270                             Earnings per share:             Basic $2.20 $2.50 $4.56 $5.23 Diluted $2.20 $2.48 $4.54 $5.19               Weighted average shares outstanding:             Basic  7,451  7,505  7,454  7,509 Diluted  7,473  7,555  7,479  7,561

# %%
## Try to read table using pandas
##(pd.read_html(str(table)))

# %% [markdown]
# ## Connect to OpenAI

# %%
import os
import openai
from configparser import ConfigParser

parser=ConfigParser()
_=parser.read('../config.cfg')
openai.api_type = "azure"
openai.api_base = parser.get('openai_api','api_ep')
openai.api_version = "2022-12-01"
openai.api_key = parser.get('openai_api','api_key')
model = parser.get('openai_api','api_model')

# %% [markdown]
# ## Parse table into pandas dataframe

# %%
prompt = "Generate a pandas dataframe from the following table\nTable=\n###\n{}\n###".format(table_txt)

response = openai.Completion.create( engine=model,  prompt=prompt, temperature=.2,  max_tokens=2000,  top_p=0.5,  frequency_penalty=0,  presence_penalty=0,  stop=None)

print('Response:')
print(response['choices'][0]['text'])
code  = response['choices'][0]['text']
# Out:
# Response:
#
#
# df = pd.DataFrame({'Three Months Ended December 31, 2022': [16.517, 36.23, 52.747, 5.69, 11.798, 17.488, 35.259, 6.844, 5.679, 2.337, 20.399, -0.06, 20.339, 3.914, 16.425, 2.2, 2.2, 7.451, 7.473],
#                     'Three Months Ended December 31, 2021': [20.779, 30.949, 51.728, 6.331, 10.629, 16.96, 34.768, 5.758, 5.379, 1.384, 22.247, 0.268, 22.515, 3.75, 18.765, 2.5, 2.48, 7.505, 7.555],
#                     'Six Months Ended December 31, 2022': [32.258, 70.611, 102.869, 9.992, 22.948, 32.94, 69.929, 13.472, 10.805, 3.735, 41.917, -0.06, 41.911, 7.93, 33.981, 4.56, 4.54, 7.454, 7.479],
#                     'Six Months Ended December 31, 2021': [37.41, 59.635, 97.045, 10.123, 20.483, 30.606, 66.439, 11.357, 9.926, 2.671, 42.485, 0.554, 43.039, 3.769, 39.27, 5.23, 5.19, 7.509, 7.561]},
#                     index=['Revenue: Product', 'Revenue: Service and other', 'Total revenue', 'Cost of revenue: Product', 'Cost of revenue: Service and other', 'Total cost of revenue', 'Gross margin', 'Research and development', 'Sales and marketing', 'General and administrative', 'Operating income', 'Other income (expense), net', 'Income before income taxes', 'Provision for income taxes', 'Net income', 'Earnings per share: Basic', 'Earnings per share: Diluted', 'Weighted average shares outstanding: Basic', 'Weighted average shares outstanding: Diluted'])
#
# df

# %%
exec(code)

# %%
df
# Out:
#                                               Three Months Ended December 31, 2022  \
# Revenue: Product                                                            16.517
# Revenue: Service and other                                                  36.230
# Total revenue                                                               52.747
# Cost of revenue: Product                                                     5.690
# Cost of revenue: Service and other                                          11.798
# Total cost of revenue                                                       17.488
# Gross margin                                                                35.259
# Research and development                                                     6.844
# Sales and marketing                                                          5.679
# General and administrative                                                   2.337
# Operating income                                                            20.399
# Other income (expense), net                                                 -0.060
# Income before income taxes                                                  20.339
# Provision for income taxes                                                   3.914
# Net income                                                                  16.425
# Earnings per share: Basic                                                    2.200
# Earnings per share: Diluted                                                  2.200
# Weighted average shares outstanding: Basic                                   7.451
# Weighted average shares outstanding: Diluted                                 7.473
#
#                                               Three Months Ended December 31, 2021  \
# Revenue: Product                                                            20.779
# Revenue: Service and other                                                  30.949
# Total revenue                                                               51.728
# Cost of revenue: Product                                                     6.331
# Cost of revenue: Service and other                                          10.629
# Total cost of revenue                                                       16.960
# Gross margin                                                                34.768
# Research and development                                                     5.758
# Sales and marketing                                                          5.379
# General and administrative                                                   1.384
# Operating income                                                            22.247
# Other income (expense), net                                                  0.268
# Income before income taxes                                                  22.515
# Provision for income taxes                                                   3.750
# Net income                                                                  18.765
# Earnings per share: Basic                                                    2.500
# Earnings per share: Diluted                                                  2.480
# Weighted average shares outstanding: Basic                                   7.505
# Weighted average shares outstanding: Diluted                                 7.555
#
#                                               Six Months Ended December 31, 2022  \
# Revenue: Product                                                          32.258
# Revenue: Service and other                                                70.611
# Total revenue                                                            102.869
# Cost of revenue: Product                                                   9.992
# Cost of revenue: Service and other                                        22.948
# Total cost of revenue                                                     32.940
# Gross margin                                                              69.929
# Research and development                                                  13.472
# Sales and marketing                                                       10.805
# General and administrative                                                 3.735
# Operating income                                                          41.917
# Other income (expense), net                                               -0.060
# Income before income taxes                                                41.911
# Provision for income taxes                                                 7.930
# Net income                                                                33.981
# Earnings per share: Basic                                                  4.560
# Earnings per share: Diluted                                                4.540
# Weighted average shares outstanding: Basic                                 7.454
# Weighted average shares outstanding: Diluted                               7.479
#
#                                               Six Months Ended December 31, 2021
# Revenue: Product                                                          37.410
# Revenue: Service and other                                                59.635
# Total revenue                                                             97.045
# Cost of revenue: Product                                                  10.123
# Cost of revenue: Service and other                                        20.483
# Total cost of revenue                                                     30.606
# Gross margin                                                              66.439
# Research and development                                                  11.357
# Sales and marketing                                                        9.926
# General and administrative                                                 2.671
# Operating income                                                          42.485
# Other income (expense), net                                                0.554
# Income before income taxes                                                43.039
# Provision for income taxes                                                 3.769
# Net income                                                                39.270
# Earnings per share: Basic                                                  5.230
# Earnings per share: Diluted                                                5.190
# Weighted average shares outstanding: Basic                                 7.509
# Weighted average shares outstanding: Diluted                               7.561

# %%
prompt = "Using the following dataframe generate python code to add year over year percentage change for each row:\ndata={}\n###\ndf = pd.DataFrame(data)\n".format(df.to_json)

response = openai.Completion.create( engine=model,  prompt=prompt, temperature=.1,  max_tokens=2000,  top_p=0.5,  frequency_penalty=0,  presence_penalty=0,  stop=None)

print('Response:')
print(response['choices'][0]['text'])
code = response['choices'][0]['text']
# Out:
# Response:
#
# df['YoY % Change'] = (df['Three Months Ended December 31, 2022'] - df['Three Months Ended December 31, 2021'])/df['Three Months Ended December 31, 2021']
# df['YoY % Change'] = df['YoY % Change'].apply(lambda x: round(x*100,2))
#
# df['YoY % Change_6M'] = (df['Six Months Ended December 31, 2022'] - df['Six Months Ended December 31, 2021'])/df['Six Months Ended December 31, 2021']
# df['YoY % Change_6M'] = df['YoY % Change_6M'].apply(lambda x: round(x*100,2))

# %%
exec(code)

# %%
df
# Out:
#                                               Three Months Ended December 31, 2022  \
# Revenue: Product                                                            16.517
# Revenue: Service and other                                                  36.230
# Total revenue                                                               52.747
# Cost of revenue: Product                                                     5.690
# Cost of revenue: Service and other                                          11.798
# Total cost of revenue                                                       17.488
# Gross margin                                                                35.259
# Research and development                                                     6.844
# Sales and marketing                                                          5.679
# General and administrative                                                   2.337
# Operating income                                                            20.399
# Other income (expense), net                                                 -0.060
# Income before income taxes                                                  20.339
# Provision for income taxes                                                   3.914
# Net income                                                                  16.425
# Earnings per share: Basic                                                    2.200
# Earnings per share: Diluted                                                  2.200
# Weighted average shares outstanding: Basic                                   7.451
# Weighted average shares outstanding: Diluted                                 7.473
#
#                                               Three Months Ended December 31, 2021  \
# Revenue: Product                                                            20.779
# Revenue: Service and other                                                  30.949
# Total revenue                                                               51.728
# Cost of revenue: Product                                                     6.331
# Cost of revenue: Service and other                                          10.629
# Total cost of revenue                                                       16.960
# Gross margin                                                                34.768
# Research and development                                                     5.758
# Sales and marketing                                                          5.379
# General and administrative                                                   1.384
# Operating income                                                            22.247
# Other income (expense), net                                                  0.268
# Income before income taxes                                                  22.515
# Provision for income taxes                                                   3.750
# Net income                                                                  18.765
# Earnings per share: Basic                                                    2.500
# Earnings per share: Diluted                                                  2.480
# Weighted average shares outstanding: Basic                                   7.505
# Weighted average shares outstanding: Diluted                                 7.555
#
#                                               Six Months Ended December 31, 2022  \
# Revenue: Product                                                          32.258
# Revenue: Service and other                                                70.611
# Total revenue                                                            102.869
# Cost of revenue: Product                                                   9.992
# Cost of revenue: Service and other                                        22.948
# Total cost of revenue                                                     32.940
# Gross margin                                                              69.929
# Research and development                                                  13.472
# Sales and marketing                                                       10.805
# General and administrative                                                 3.735
# Operating income                                                          41.917
# Other income (expense), net                                               -0.060
# Income before income taxes                                                41.911
# Provision for income taxes                                                 7.930
# Net income                                                                33.981
# Earnings per share: Basic                                                  4.560
# Earnings per share: Diluted                                                4.540
# Weighted average shares outstanding: Basic                                 7.454
# Weighted average shares outstanding: Diluted                               7.479
#
#                                               Six Months Ended December 31, 2021  \
# Revenue: Product                                                          37.410
# Revenue: Service and other                                                59.635
# Total revenue                                                             97.045
# Cost of revenue: Product                                                  10.123
# Cost of revenue: Service and other                                        20.483
# Total cost of revenue                                                     30.606
# Gross margin                                                              66.439
# Research and development                                                  11.357
# Sales and marketing                                                        9.926
# General and administrative                                                 2.671
# Operating income                                                          42.485
# Other income (expense), net                                                0.554
# Income before income taxes                                                43.039
# Provision for income taxes                                                 3.769
# Net income                                                                39.270
# Earnings per share: Basic                                                  5.230
# Earnings per share: Diluted                                                5.190
# Weighted average shares outstanding: Basic                                 7.509
# Weighted average shares outstanding: Diluted                               7.561
#
#                                               YoY % Change  YoY % Change_6M
# Revenue: Product                                    -20.51           -13.77
# Revenue: Service and other                           17.06            18.41
# Total revenue                                         1.97             6.00
# Cost of revenue: Product                            -10.12            -1.29
# Cost of revenue: Service and other                   11.00            12.03
# Total cost of revenue                                 3.11             7.63
# Gross margin                                          1.41             5.25
# Research and development                             18.86            18.62
# Sales and marketing                                   5.58             8.86
# General and administrative                           68.86            39.84
# Operating income                                     -8.31            -1.34
# Other income (expense), net                        -122.39          -110.83
# Income before income taxes                           -9.66            -2.62
# Provision for income taxes                            4.37           110.40
# Net income                                          -12.47           -13.47
# Earnings per share: Basic                           -12.00           -12.81
# Earnings per share: Diluted                         -11.29           -12.52
# Weighted average shares outstanding: Basic           -0.72            -0.73
# Weighted average shares outstanding: Diluted         -1.09            -1.08

# %%
prompt = "Using the following data generate code to identify top changes in percentages in data:\ndata={}\n###\ndf = pd.DataFrame(data)\n".format(df.to_json)

response = openai.Completion.create( engine=model,  prompt=prompt, temperature=.1,  max_tokens=2000,  top_p=0.5,  frequency_penalty=0,  presence_penalty=0,  stop=None)

print('Response:')
print(response['choices'][0]['text'])
code = response['choices'][0]['text']
# Out:
# Response:
#
# # Calculate the percentage change between the two periods
# df['YoY % Change'] = (df['Three Months Ended December 31, 2022'] - df['Three Months Ended December 31, 2021']) / df['Three Months Ended December 31, 2021'] * 100
# df['YoY % Change_6M'] = (df['Six Months Ended December 31, 2022'] - df['Six Months Ended December 31, 2021']) / df['Six Months Ended December 31, 2021'] * 100
#
# # Sort the dataframe by the percentage change
# df.sort_values(by='YoY % Change', ascending=False, inplace=True)
#
# # Print the top 5 changes
# print(df.head(5))

# %%
exec(code)
# Out:
#                                     Three Months Ended December 31, 2022  \
# General and administrative                                         2.337
# Research and development                                           6.844
# Revenue: Service and other                                        36.230
# Cost of revenue: Service and other                                11.798
# Sales and marketing                                                5.679
#
#                                     Three Months Ended December 31, 2021  \
# General and administrative                                         1.384
# Research and development                                           5.758
# Revenue: Service and other                                        30.949
# Cost of revenue: Service and other                                10.629
# Sales and marketing                                                5.379
#
#                                     Six Months Ended December 31, 2022  \
# General and administrative                                       3.735
# Research and development                                        13.472
# Revenue: Service and other                                      70.611
# Cost of revenue: Service and other                              22.948
# Sales and marketing                                             10.805
#
#                                     Six Months Ended December 31, 2021  \
# General and administrative                                       2.671
# Research and development                                        11.357
# Revenue: Service and other                                      59.635
# Cost of revenue: Service and other                              20.483
# Sales and marketing                                              9.926
#
#                                     YoY % Change  YoY % Change_6M
# General and administrative             68.858382        39.835268
# Research and development               18.860716        18.622876
# Revenue: Service and other             17.063556        18.405299
# Cost of revenue: Service and other     10.998212        12.034370
# Sales and marketing                     5.577245         8.855531

# %%
df
# Out:
#                                               Three Months Ended December 31, 2022  \
# General and administrative                                                   2.337
# Research and development                                                     6.844
# Revenue: Service and other                                                  36.230
# Cost of revenue: Service and other                                          11.798
# Sales and marketing                                                          5.679
# Provision for income taxes                                                   3.914
# Total cost of revenue                                                       17.488
# Total revenue                                                               52.747
# Gross margin                                                                35.259
# Weighted average shares outstanding: Basic                                   7.451
# Weighted average shares outstanding: Diluted                                 7.473
# Operating income                                                            20.399
# Income before income taxes                                                  20.339
# Cost of revenue: Product                                                     5.690
# Earnings per share: Diluted                                                  2.200
# Earnings per share: Basic                                                    2.200
# Net income                                                                  16.425
# Revenue: Product                                                            16.517
# Other income (expense), net                                                 -0.060
#
#                                               Three Months Ended December 31, 2021  \
# General and administrative                                                   1.384
# Research and development                                                     5.758
# Revenue: Service and other                                                  30.949
# Cost of revenue: Service and other                                          10.629
# Sales and marketing                                                          5.379
# Provision for income taxes                                                   3.750
# Total cost of revenue                                                       16.960
# Total revenue                                                               51.728
# Gross margin                                                                34.768
# Weighted average shares outstanding: Basic                                   7.505
# Weighted average shares outstanding: Diluted                                 7.555
# Operating income                                                            22.247
# Income before income taxes                                                  22.515
# Cost of revenue: Product                                                     6.331
# Earnings per share: Diluted                                                  2.480
# Earnings per share: Basic                                                    2.500
# Net income                                                                  18.765
# Revenue: Product                                                            20.779
# Other income (expense), net                                                  0.268
#
#                                               Six Months Ended December 31, 2022  \
# General and administrative                                                 3.735
# Research and development                                                  13.472
# Revenue: Service and other                                                70.611
# Cost of revenue: Service and other                                        22.948
# Sales and marketing                                                       10.805
# Provision for income taxes                                                 7.930
# Total cost of revenue                                                     32.940
# Total revenue                                                            102.869
# Gross margin                                                              69.929
# Weighted average shares outstanding: Basic                                 7.454
# Weighted average shares outstanding: Diluted                               7.479
# Operating income                                                          41.917
# Income before income taxes                                                41.911
# Cost of revenue: Product                                                   9.992
# Earnings per share: Diluted                                                4.540
# Earnings per share: Basic                                                  4.560
# Net income                                                                33.981
# Revenue: Product                                                          32.258
# Other income (expense), net                                               -0.060
#
#                                               Six Months Ended December 31, 2021  \
# General and administrative                                                 2.671
# Research and development                                                  11.357
# Revenue: Service and other                                                59.635
# Cost of revenue: Service and other                                        20.483
# Sales and marketing                                                        9.926
# Provision for income taxes                                                 3.769
# Total cost of revenue                                                     30.606
# Total revenue                                                             97.045
# Gross margin                                                              66.439
# Weighted average shares outstanding: Basic                                 7.509
# Weighted average shares outstanding: Diluted                               7.561
# Operating income                                                          42.485
# Income before income taxes                                                43.039
# Cost of revenue: Product                                                  10.123
# Earnings per share: Diluted                                                5.190
# Earnings per share: Basic                                                  5.230
# Net income                                                                39.270
# Revenue: Product                                                          37.410
# Other income (expense), net                                                0.554
#
#                                               YoY % Change  YoY % Change_6M
# General and administrative                       68.858382        39.835268
# Research and development                         18.860716        18.622876
# Revenue: Service and other                       17.063556        18.405299
# Cost of revenue: Service and other               10.998212        12.034370
# Sales and marketing                               5.577245         8.855531
# Provision for income taxes                        4.373333       110.400637
# Total cost of revenue                             3.113208         7.625956
# Total revenue                                     1.969920         6.001340
# Gross margin                                      1.412218         5.252939
# Weighted average shares outstanding: Basic       -0.719520        -0.732454
# Weighted average shares outstanding: Diluted     -1.085374        -1.084513
# Operating income                                 -8.306738        -1.336942
# Income before income taxes                       -9.664668        -2.620879
# Cost of revenue: Product                        -10.124783        -1.294083
# Earnings per share: Diluted                     -11.290323       -12.524085
# Earnings per share: Basic                       -12.000000       -12.810707
# Net income                                      -12.470024       -13.468296
# Revenue: Product                                -20.511093       -13.771719
# Other income (expense), net                    -122.388060      -110.830325
